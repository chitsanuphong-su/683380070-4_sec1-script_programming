# %% [markdown]
# # Activity 2.1: Logic Tracing Sandbox

# %%
# Block A: Evaluation Check
temp = 25
is_raining = True

if temp > 20 and not is_raining:
  print("Perfect day for a picnic!")
elif temp <= 20 or is_raining:
  print("Stay indoors or bring an umbrella.") # Expected output matches here
else:
  print("Unsure about the weather.")

# Block B: Vectorized Filter
phrase = "Python 2026 Engine"
consonants = {c.lower() for c in phrase if c.isalpha() and c.lower() not in 'aeiou'}
print(f"Unique consonants: {consonants}")
# Out:
# Stay indoors or bring an umbrella.
# Unique consonants: {'g', 'h', 'n', 't', 'p', 'y'}

# %% [markdown]
# ### ถ้าอุญหภูมิมากกว่า 20 องศา และฝนไม่ตก ให้ print ข้อความว่า "Perfect day for a picnic!"
#
# ### ถ้าอุณหภูมิน้อยกว่าหรือเท่ากับ 20 องศา และฝนตก ให้ print ข้อความว่า "Stay indoors or bring an umbrella."
#
# ### และถ้าไม่เข้าเงื่อนไขทั้งสอง ให้ print ข้อความว่า "Unsure about the weather."
#
# ### ซึ่งอุณหภูมิในโค้ดคือ 25 องศา และ ฝนตก เข้าเงื่อนไขที่2
#
# ### ผลลัพธ์ คือ "Stay indoors or bring an umbrella."

# %% [markdown]
# ---
#
# # Activity 2.2: Choose Your Own Adventure Architectures

# %% [markdown]
# ## Ghost Escape
#
# ### เป็นเกมหนีผีตามด่านต่างๆ จะมีจุดเซฟที่ปลายทางตอนจบด่านนั้นๆ
#
# ### input จะมี ชื่อผู้เล่น(user_name), ด่านถัดไป(next_level)
#
# ### ตัวแปร จะมี level(int), is_safe(bool)
#
# ### ถ้า is_safe มีค่าเป็น True หมายความว่าถึงจุดเซฟแล้ว ให้ level +1 ก็คือผ่านด่านให้เพิ่มเลเวลถัดไป
#
# ### ถ้า is_safe มี่าเป็น False หมานความว่ายังไใ่ถึงจุกเซฟ หรือก็คือตายนั่นเอง ให้ level ยังคงอยู่ที่เดิมและเริ่มเล่นใหม่จนกว่า ค่า is_safe จะเป็น True
#
# ### การเล่นจะเป็นการใช้ลูปไปเรื่อยๆ เมื่อจะขึ้นด่านถัดไปจะให้ใส่ input ของค่า next_level ก่อนว่า Yes หรือ No ถ้า Yes ให้เล่นด่านถัดไป ถ้า No คือหยุดเล่น
